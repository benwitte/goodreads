# %%
#impooooooorrrrrrt

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import re
import seaborn as sns
plt.style.use('ggplot')
import statsmodels.api as sm
from scipy import stats
from scipy.stats import linregress
# Out:
# /Users/witte/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#read in data frame
#clean remaining faulty data falling outside year range
#combine new and young adult for more accurate reading of pattern

goodreads = pd.DataFrame.from_csv('~/Desktop/NYCDSA/python/webscraping_project/goodreads/goodreads.csv')
goodreads = goodreads.loc[(goodreads['pubyear'] > 1979) & (goodreads['pubyear'] < 2018), ]
goodreads['genre'].replace('New Adult','Young Adult', inplace=True)
goodreads.head()
# Out:
#                      avgrating  \
# author
# David Levithan            3.85
# Misty Bernall             3.90
# Nicholas D. Kristof       4.30
# Nicholas Sparks           4.14
# Susanna Clarke            3.81
#
#                                                                 awards  \
# author
# David Levithan                                                     NaN
# Misty Bernall                                                      NaN
# Nicholas D. Kristof                                                NaN
# Nicholas Sparks            Goodreads Choice Award for Chick Lit (2009)
# Susanna Clarke       Hugo Award for Best Novel (2005),Man Booker Pr...
#
#                      five_stars  four_stars        genre  numpages  one_stars  \
# author
# David Levithan            19217       17057  Young Adult       185       2178
# Misty Bernall              4766        3883   Nonfiction       140        358
# Nicholas D. Kristof       22760       13754   Nonfiction       294        533
# Nicholas Sparks          206519      146877      Romance       390       7613
# Susanna Clarke            56990       52046   Historical      1006       8534
#
#                             origpubdate  pubyear             pubdate  \
# author
# David Levithan       September 9th 2003     2003       May 10th 2005
# Misty Bernall        September 9th 1999     1999    January 1st 2002
# Nicholas D. Kristof  September 8th 2008     2008  September 8th 2009
# Nicholas Sparks      September 8th 2008     2008  September 8th 2009
# Susanna Clarke       September 8th 2004     2004     August 1st 2006
#
#                                     publisher  three_stars  \
# author
# David Levithan                Alfred A. Knopf        13110
# Misty Bernall         Plough Publishing House         3117
# Nicholas D. Kristof    Knopf Publishing Group         5525
# Nicholas Sparks      Grand Central Publishing        81001
# Susanna Clarke                      Tor Books        33035
#
#                                                                  title  \
# author
# David Levithan                                           Boy Meets Boy
# Misty Bernall        She Said Yes: The Unlikely Martyrdom of Cassie...
# Nicholas D. Kristof  Half the Sky: Turning Oppression Into Opportun...
# Nicholas Sparks                                          The Last Song
# Susanna Clarke                           Jonathan Strange & Mr Norrell
#
#                      totalratings  totalreviews  two_stars
# author
# David Levithan              55486          3404       3924
# Misty Bernall               13062           633        938
# Nicholas D. Kristof         43828          4806       1256
# Nicholas Sparks            460561         11294      18551
# Susanna Clarke             165445         12138      14840

# %%
#removes low-end outliers from genre count to determine median number of ratings for popular genres
#creates new column dividing sum of totalratings by 1,000,000
#plots number of ratings by genre

filtered_gg=goodreads.groupby('genre').filter(lambda x: len(x)>60)
filtered_gg['totalratings_millions'] = filtered_gg['totalratings']/100000
plt.figure(figsize=(12,6))
filtered_gg.groupby('genre')['totalratings_millions'].sum().sort_values(ascending=False).plot.bar()
plt.xlabel('Genre')
plt.ylabel('Sum of Books Read (in Millions)')
plt.title('Number of Books Marked as "Read", by Genre')

plt.rcParams.update({'font.size': 17})
# Out:
# /Users/witte/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
filtered_gg=goodreads.groupby('genre').filter(lambda x: len(x)>60)
plt.figure(figsize=(12,6))
filtered_gg.groupby('genre')['genre'].count().sort_values(ascending=False).plot.bar()
plt.xlabel('Genre')
plt.ylabel('Number of Books')
plt.title('Count of Books by Genre, 1980-2017')
plt.rcParams.update({'font.size': 17})

# %%
# plots rise of new adult/young adult books over time

plt.figure(figsize=(12,6))
ya_filter = goodreads[goodreads['genre'] == 'Young Adult']
ya_filter.groupby('pubyear')['genre'].count().plot.bar()
plt.xlabel('Year')
plt.ylabel('Number of Books')
plt.title('Number of YA Books in the Top 200 Most Popular Books, Annually')
plt.rcParams.update({'font.size': 17})

# %%
plt.figure(figsize=(12,6))
ya_filter.groupby('pubyear')['avgrating'].median().plot.bar()
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.title('Average Rating by Year')

plt.rcParams.update({'font.size': 18})

# %%
#counting the number of awards each book has received

awards_grouping = goodreads
awards_grouping['awards']=awards_grouping['awards'].fillna('0')
awards_grouping['numawards']= awards_grouping['awards'].str.split(',').str.len()
awards_grouping.loc[awards_grouping["awards"]=='0', 'numawards']=0
awards_grouping.head()


#extraneous code

#awards_grouping = filtered_gg.loc[filtered_gg['awards'].isnull()==False]
#awards_grouping['awards'].str.split(',').agg(len)
# awards_grouping['numawards'] = awards_grouping['numawards'].fillna(0)
# Out:
#                      avgrating  \
# author
# David Levithan            3.85
# Misty Bernall             3.90
# Nicholas D. Kristof       4.30
# Nicholas Sparks           4.14
# Susanna Clarke            3.81
#
#                                                                 awards  \
# author
# David Levithan                                                       0
# Misty Bernall                                                        0
# Nicholas D. Kristof                                                  0
# Nicholas Sparks            Goodreads Choice Award for Chick Lit (2009)
# Susanna Clarke       Hugo Award for Best Novel (2005),Man Booker Pr...
#
#                      five_stars  four_stars        genre  numpages  one_stars  \
# author
# David Levithan            19217       17057  Young Adult       185       2178
# Misty Bernall              4766        3883   Nonfiction       140        358
# Nicholas D. Kristof       22760       13754   Nonfiction       294        533
# Nicholas Sparks          206519      146877      Romance       390       7613
# Susanna Clarke            56990       52046   Historical      1006       8534
#
#                             origpubdate  pubyear             pubdate  \
# author
# David Levithan       September 9th 2003     2003       May 10th 2005
# Misty Bernall        September 9th 1999     1999    January 1st 2002
# Nicholas D. Kristof  September 8th 2008     2008  September 8th 2009
# Nicholas Sparks      September 8th 2008     2008  September 8th 2009
# Susanna Clarke       September 8th 2004     2004     August 1st 2006
#
#                                     publisher  three_stars  \
# author
# David Levithan                Alfred A. Knopf        13110
# Misty Bernall         Plough Publishing House         3117
# Nicholas D. Kristof    Knopf Publishing Group         5525
# Nicholas Sparks      Grand Central Publishing        81001
# Susanna Clarke                      Tor Books        33035
#
#                                                                  title  \
# author
# David Levithan                                           Boy Meets Boy
# Misty Bernall        She Said Yes: The Unlikely Martyrdom of Cassie...
# Nicholas D. Kristof  Half the Sky: Turning Oppression Into Opportun...
# Nicholas Sparks                                          The Last Song
# Susanna Clarke                           Jonathan Strange & Mr Norrell
#
#                      totalratings  totalreviews  two_stars  numawards
# author
# David Levithan              55486          3404       3924          0
# Misty Bernall               13062           633        938          0
# Nicholas D. Kristof         43828          4806       1256          0
# Nicholas Sparks            460561         11294      18551          1
# Susanna Clarke             165445         12138      14840          5

# %%
#Proving awards have abosulutely no impact on how much people like books

plt.figure(figsize = (13,7))
awards_grouping.groupby('numawards')['avgrating'].median().plot.bar()
plt.xlabel('Number of Awards')
plt.ylabel('Median Rating')
plt.title('Impact of Awards on Rating')
plt.rcParams.update({'font.size': 17})

# %%
#On the other hand, suggesting that the more awards you get, the more people read your book - though it's a chicken/egg
# unless you have access to award date and when marked as read

plt.figure(figsize = (12,6))
awards_grouping.groupby('numawards')['totalratings'].median().plot.bar()
plt.xlabel('Number of Awards')
plt.ylabel('Median Number of Ratings')
plt.title('Impact of Awards on Readership')
plt.rcParams.update({'font.size': 17})

# %%
plt.figure(figsize = (12,6))
ratings_by_year = goodreads[['pubyear', 'avgrating']].dropna()
plt.scatter(ratings_by_year['pubyear'], ratings_by_year['avgrating'])


#Need to set range to 1980-2017. All data outside is invalid

# %%
#statistical summary of data with avg rating, numpages, pubyear and numawards and independent
# variables and totalratings as dependent

X5 = sm.add_constant(awards_grouping[awards_grouping.columns[[0,5,8,16]]]) # independent variables
y5 = awards_grouping.totalratings # dependent variable
est = sm.OLS(y5,X5)
est2 = est.fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           totalratings   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     102.1
# Date:                Tue, 15 May 2018   Prob (F-statistic):           1.14e-84
# Time:                        22:58:40   Log-Likelihood:                -96388.
# No. Observations:                7168   AIC:                         1.928e+05
# Df Residuals:                    7163   BIC:                         1.928e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.324e+06   3.66e+05    -11.822      0.000   -5.04e+06   -3.61e+06
# avgrating   4.761e+04   8352.905      5.700      0.000    3.12e+04     6.4e+04
# numpages      22.2194      9.509      2.337      0.019       3.580      40.859
# pubyear     2090.1449    181.517     11.515      0.000    1734.318    2445.972
# numawards   3.308e+04   2318.832     14.267      0.000    2.85e+04    3.76e+04
# ==============================================================================
# Omnibus:                    13956.443   Durbin-Watson:                   1.520
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         39868627.543
# Skew:                          15.274   Prob(JB):                         0.00
# Kurtosis:                     367.082   Cond. No.                     3.76e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.76e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
linregress(awards_grouping['avgrating'], awards_grouping['totalratings'])
# Out:
# LinregressResult(slope=41476.018700180575, intercept=-106921.63936072125, rvalue=0.0579667834072429, pvalue=9.0624283415734903e-07, stderr=8438.1760549519131)

# %%
#plotting a linear regression line over a graph of x = avgrating, y = totalratings


linregress(awards_grouping['avgrating'], awards_grouping['totalratings'])


plt.figure(figsize = (12,6))
plt.scatter(awards_grouping['avgrating'], awards_grouping['totalratings'])
plt.ylim(0, 300000)
#plt.xlim(3.5,4.5)
linregress(awards_grouping['avgrating'], awards_grouping['totalratings'])
plt.xlim(3.,4.9)
plt.xlabel('Average Rating')
plt.ylabel('Number of Readers')
plt.title('Impact of Rating on Readership')


f = lambda x: 41476.018700180575*x -106921.63936072125
# x values of line to plot
x = awards_grouping['avgrating']
# plot fit
plt.plot(x,f(x), c="blue")

#better take min and max of x values
#
plt.legend()
plt.show()
plt.rcParams.update({'font.size': 17})

# %%
# Creates a new df filtered by publishers that ahve more than 80 books in the entire dataset
# creats a column that aggregates

publisher_filter = goodreads.groupby('publisher').filter(lambda x: len(x)>80)
publisher_filter = publisher_filter.groupby(['publisher']).agg({'totalratings': 'sum'}).sort_values(by = 'totalratings', ascending=False).reset_index()
publisher_filter['totalratings_millions'] = publisher_filter['totalratings']/100000
#publisher_filter = publisher_filter.groupby('publisher')['totalratings'].sum().sort_values(ascending=False)

# %%
publisher_filter.head()
# Out:
#                    publisher  totalratings  totalratings_millions
# 0  Little, Brown and Company      15795183              157.95183
# 1                     Bantam       8141774               81.41774
# 2                    Vintage       7807102               78.07102
# 3   Grand Central Publishing       7046017               70.46017
# 4              HarperCollins       6525651               65.25651

# %%
# Plotting top Publishers by # Books Read

plt.figure(figsize=(12,6))
# x = publisher_filter['publisher']
# y = publisher_filter['totalratings_millions']
publisher_filter.groupby('publisher')['totalratings_millions'].sum().sort_values(ascending=False).plot.bar()
plt.xlabel('Publisher')
plt.ylabel('Number of Books (in Millions)')
plt.title('Number of Books Read, by Publisher')

plt.rcParams.update({'font.size': 20})

# %%
# Continuing to display how nothing has any effect on rating

# goodreads.groupby('publisher').filter(lambda x: len(x)>80)

genre_filter = goodreads.groupby('genre').filter(lambda x: len(x)>80)
plt.figure(figsize = (13,7))
genre_filter.groupby('genre')['avgrating'].median().plot.bar()
plt.xlabel('genre')
plt.ylabel('Median Rating')
plt.title('Impact of Genre on Rating')
plt.rcParams.update({'font.size': 17})
